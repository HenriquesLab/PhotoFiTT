# %%
import sys
sys.path.append("/home/ocb/HardDrive_4TB/EGM/PHX/PhotoFITT/photofitt/")
from utils.normalisation import normalise_phc_timelapse
import tifffile
from tifffile import imsave
import os
import numpy as np
import cv2
import czifile as zis
import shutil
from skimage import io
from skimage import exposure


def normalise_data(Source_QC_folder, Target_QC_folder, Normalisation_QC_source, Normalisation_QC_target, Im_path):
    if Normalisation_QC_source == "Contrast stretching":

        for filename in os.listdir(Source_QC_folder):

            img = io.imread(os.path.join(Source_QC_folder,filename)).astype(np.float32)
            short_name = os.path.splitext(filename)

            p2, p99 = np.percentile(img, (1., 99.9))
            img = exposure.rescale_intensity(img, in_range=(p2, p99))

            img = 255 * img # Now scale by 255
            img = img.astype(np.uint8)
            cv2.imwrite(os.path.join(Im_path, "A", "test", f"{short_name[0]}.png"), img)

    if Normalisation_QC_target == "Contrast stretching":
        for filename in os.listdir(Target_QC_folder):

            img = io.imread(os.path.join(Target_QC_folder,filename)).astype(np.float32)
            short_name = os.path.splitext(filename)

            p2, p99 = np.percentile(img, (1., 99.9))
            img = exposure.rescale_intensity(img, in_range=(p2, p99))

            img = 255 * img # Now scale by 255
            img = img.astype(np.uint8)
            cv2.imwrite(os.path.join(Im_path, "B", "test", f"{short_name[0]}.png"), img)

    if Normalisation_QC_source == "Adaptive Equalization":
        for filename in os.listdir(Source_QC_folder):

            img = io.imread(os.path.join(Source_QC_folder,filename))
            short_name = os.path.splitext(filename)

            img = exposure.equalize_adapthist(img, clip_limit=0.03)

            img = 255 * img # Now scale by 255
            img = img.astype(np.uint8)
            cv2.imwrite(os.path.join(Im_path, "A", "test", f"{short_name[0]}.png"), img)


    if Normalisation_QC_target == "Adaptive Equalization":
        for filename in os.listdir(Target_QC_folder):

            img = io.imread(os.path.join(Target_QC_folder,filename))
            short_name = os.path.splitext(filename)

            img = exposure.equalize_adapthist(img, clip_limit=0.03)

            img = 255 * img # Now scale by 255
            img = img.astype(np.uint8)
            cv2.imwrite(os.path.join(Im_path, "B", "test", f"{short_name[0]}.png"), img)

    if Normalisation_QC_source == "None":
        for filename in os.listdir(Source_QC_folder):
            img = io.imread(os.path.join(Source_QC_folder,filename))
            short_name = os.path.splitext(filename)
            cv2.imwrite(os.path.join(Im_path, "A", "test", f"{short_name[0]}.png"), img)
            
    if Normalisation_QC_target == "None":
        for filename in os.listdir(Target_QC_folder):
            img = io.imread(os.path.join(Target_QC_folder,filename))
            short_name = os.path.splitext(filename)
            cv2.imwrite(os.path.join(Im_path, "B", "test", f"{short_name[0]}.png"), img)

def stack2im(path2stack, path2im, ph_normalisation=False):
    f = zis.CziFile(path2stack)
    stack = f.asarray()
    stack = stack.squeeze()
    file_name = os.path.basename(path2stack)
    file_name = os.path.splitext(file_name)
    print(f"{file_name} file loaded in python")
    os.makedirs(path2im, exist_ok=True)
    for t in range(len(stack)):
        if ph_normalisation:
            im = normalise_phc_timelapse(stack[t], keep_mean=False)
            # note that images are float 32 with negative values
            im = (im-np.min(im))/(np.max(im) - np.min(im))
        else:
            im = stack[t]
        cv2.imwrite(os.path.join(path2im, f"{file_name[0]}_{t:04d}.tif"), im)
    #Find image XY dimension
    Image_Y = im.shape[0]
    Image_X = im.shape[1]
    return min(Image_Y, Image_X)
    


def prepare_im_sequence(path2im, working_dir, pix2pix_code_dir, normalisation="Contrast stretching"):
    
    # Here we need to move the data to be analysed so that pix2pix can find them
    Saving_path_prediction= working_dir
    
    if os.path.exists(Saving_path_prediction):
        shutil.rmtree(Saving_path_prediction)
    os.makedirs(Saving_path_prediction, exist_ok=True)
    
    imageA_folder = os.path.join(Saving_path_prediction, "A")
    os.makedirs(imageA_folder, exist_ok=True)
    
    imageB_folder = os.path.join(Saving_path_prediction, "B")
    os.makedirs(imageB_folder, exist_ok=True)
    
    imageAB_folder = os.path.join(Saving_path_prediction, "AB")
    os.makedirs(imageAB_folder, exist_ok=True)
    
    testAB_Folder = os.path.join(imageAB_folder, "test")
    os.makedirs(testAB_Folder, exist_ok=True)
    
    testA_Folder = os.path.join(imageA_folder, "test")
    os.makedirs(testA_Folder, exist_ok=True)
    
    testB_Folder = os.path.join(imageB_folder, "test")
    os.makedirs(testB_Folder, exist_ok=True)
    
    # Normalise the image sequence with the pix2pix normalisation
    print(path2im)
    print(Saving_path_prediction)
    normalise_data(path2im, path2im, normalisation, normalisation, Saving_path_prediction)

    # Process normalised data for pix2pix to process it
    os.chdir(pix2pix_code_dir)
    # !python3 pytorch-CycleGAN-and-pix2pix/datasets/combine_A_and_B.py --fold_A "$imageA_folder" --fold_B "$imageB_folder" --fold_AB "$imageAB_folder"
    print("Images ready to be processed")
    print(f'AB folder placed in {imageAB_folder}')
    
    return imageAB_folder
    
def process_im_sequence(pix2pix_code_dir, imageAB_folder, Prediction_model_name, Prediction_model_path, Result_folder, Nb_files_Data_folder, patch_size=1024, checkpoint="latest", nc=1):
    
    if not patch_size % 256 == 0:
      patch_size = ((int(patch_size / 256)) * 256)
      print (" Your image dimensions are not divisible by 256; therefore your images have now been resized to:",patch_size)
    
    if patch_size < 256:
      patch_size = 256

    
    os.chdir(pix2pix_code_dir)
    # !python3 pytorch-CycleGAN-and-pix2pix/test.py --dataroot "$imageAB_folder" --name "$Prediction_model_name" --model pix2pix --no_dropout --preprocess scale_width --load_size $patch_size --crop_size $patch_size --results_dir "$Result_folder" --checkpoints_dir "$Prediction_model_path" --num_test $Nb_files_Data_folder --epoch $checkpoint --input_nc "$nc" --output_nc "$nc" --dataset_mode "aligned"
    print("Images processed already")


def frames2videos_pix2pix(path2im):
    path2real = os.path.join(path2im, "images_real_A")
    path2fake = os.path.join(path2im, "images_fake_B")
    
    files = os.listdir(path2real)
    
    video_names = [i.split("_0000_")[0] for i in files if i.__contains__("_0000_")]
    
    path2real_reconstructions = os.path.join(path2im, "videos_real_A")
    path2fake_reconstructions = os.path.join(path2im, "videos_fake_B")
    os.makedirs(path2real_reconstructions, exist_ok=True)
    os.makedirs(path2fake_reconstructions, exist_ok=True)
    for v in video_names:
        video = [j for j in files if j.__contains__(v)]
        video.sort()
        real_video = []
        fake_video = []
        
        for j in video:
            real_video.append(cv2.imread(os.path.join(path2real, j))[...,0])
            fake_filename = j.split("_real_A.png")[0] + "_fake_B.png"
            
            fake_video.append(cv2.imread(os.path.join(path2fake, fake_filename))[...,0])
        real_video = np.array(real_video)
        fake_video = np.array(fake_video)
        imsave(os.path.join(path2real_reconstructions, f"{v}.tif"), real_video)
        imsave(os.path.join(path2fake_reconstructions, f"{v}.tif"), fake_video)
        print(f"{v} processed")
        
def process_pix2pix(path2data, pix2pix_model_path, Result_folder, pix2pix_code_dir, working_dir, checkpoint="latest", normalisation="Contrast stretching", nc=1):
    folders = os.listdir(path2data)
    folders.sort
    print(folders)
    os.makedirs(Result_folder, exist_ok=True)
    path2imsequence = os.path.join(working_dir, "image_sequence")
    Prediction_model_name = os.path.basename(pix2pix_model_path)
    Prediction_model_path = os.path.dirname(pix2pix_model_path)

    if os.path.exists(path2imsequence):
        shutil.rmtree(path2imsequence)
    
    for i in range(len(folders)):
        f = folders[i]
        if f[0] != '.':
            if not f.__contains__('.'):

                process_pix2pix(os.path.join(path2data, f), pix2pix_model_path, os.path.join(Result_folder, f), 
                                pix2pix_code_dir, working_dir, checkpoint=checkpoint, 
                                normalisation=normalisation, nc=nc)
            elif f.__contains__('.czi'):
                print(f)
                # Convert the CZI stack into a normalised image sequence and save it in a general folder.
                patch_size = stack2im(os.path.join(path2data, f), path2imsequence, ph_normalisation=True)
                print(f'Images stored in {path2imsequence}')
            
                imageAB_folder = prepare_im_sequence(path2imsequence, os.path.join(working_dir, "prepared_data"), pix2pix_code_dir, normalisation=normalisation)
                
                Nb_files_Data_folder = len(os.listdir(os.path.join(imageAB_folder, "test")))+10
                
                process_im_sequence(pix2pix_code_dir, imageAB_folder, Prediction_model_name, Prediction_model_path,
                                    Result_folder, Nb_files_Data_folder, patch_size=patch_size, checkpoint=checkpoint, nc=nc)

                Checkpoint_name = "test_"+str(checkpoint)

                
                Prediction_results_folder = os.path.join(Result_folder, Prediction_model_name, Checkpoint_name, "images")
                
                Prediction_results_images = os.listdir(Prediction_results_folder)
                
                for f in Prediction_results_images:
                  if (f.endswith("_real_B.png")):
                    os.remove(Prediction_results_folder+"/"+f)
                
                
                os.makedirs(os.path.join(Prediction_results_folder + "_fake_B"),exist_ok=True)
                os.makedirs(os.path.join(Prediction_results_folder + "_real_A"),exist_ok=True)
                
                for f in os.listdir(Prediction_results_folder):
                    if f.endswith("fake_B.png"):
                        shutil.copy(os.path.join(Prediction_results_folder, f),
                                    os.path.join(Prediction_results_folder + "_fake_B", f))
                    elif f.endswith("real_A.png"):
                        shutil.copy(os.path.join(Prediction_results_folder, f),
                                    os.path.join(Prediction_results_folder + "_real_A", f))
                # Remove the images
                shutil.rmtree(Prediction_results_folder)

                if os.path.exists(path2imsequence):
                    shutil.rmtree(path2imsequence)

def digest_predictions(Result_folder):
    folders = os.listdir(Result_folder)
    folders.sort
    print(folders)
    if "images_fake_B" in folders:
        frames2videos_pix2pix(Result_folder)
    else:
        for f in folders:
            if f[0] != '.':
                digest_predictions(os.path.join(Result_folder, f))

# %%
#Here, we install libraries which are not already included in Colab.
#!git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
import os
pix2pix_working_directory = "/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/"
pix2pix_code_dir = "/home/ocb/HardDrive_4TB/EGM/PHX/PhotoFITT/notebooks/deep-learning/pix2pix/"
#Result_folder = "/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL
024
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS	[default: ./checkpoints]
#                 crop_size: 1024                          	[default: 256]
#                  dataroot: /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1                             	[default: 3]
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 1024                          	[default: 256]
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
#                      name: pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_256
#                       ngf: 64
#                no_dropout: True                          	[default: False]
#                   no_flip: False
#                      norm: batch
#                  num_test: 131                           	[default: 50]
#               num_threads: 4
#                 output_nc: 1                             	[default: 3]
#                     phase: test
#                preprocess: scale_width                   	[default: resize_and_crop]
#               results_dir: /media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/CHO-SYNCHRO-nuclei/20230504_630_day/Individual	[default: ./results/]
#            serial_batches: False
#                    suffix:
#                 use_wandb: False
#                   verbose: False
#        wandb_project_name: CycleGAN-and-pix2pix
# ----------------- End -------------------
# dataset [AlignedDataset] was created
# initialize network with normal
# model [Pix2PixModel] was created
# loading the model from /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 54.408 M
# -----------------------------------------------
# creating web directory /media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/CHO-SYNCHRO-nuclei/20230504_630_day/Individual/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024/test_latest
# processing (0000)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0000.png']
# processing (0005)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0005.png']
# processing (0010)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0010.png']
# processing (0015)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0015.png']
# processing (0020)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0020.png']
# processing (0025)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0025.png']
# processing (0030)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0030.png']
# processing (0035)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0035.png']
# processing (0040)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0040.png']
# processing (0045)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0045.png']
# processing (0050)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0050.png']
# processing (0055)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0055.png']
# processing (0060)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0060.png']
# processing (0065)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0065.png']
# processing (0070)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0070.png']
# processing (0075)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0075.png']
# processing (0080)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0080.png']
# processing (0085)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0085.png']
# processing (0090)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0090.png']
# processing (0095)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0095.png']
# processing (0100)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0100.png']
# processing (0105)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0105.png']
# processing (0110)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0110.png']
# processing (0115)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0115.png']
# processing (0120)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-02-P8-A01_0120.png']
# Images processed already
# CHO_day_630__live-02-Scene-03-P7-A01.czi
# ('CHO_day_630__live-02-Scene-03-P7-A01', '.czi') file loaded in python
# Images stored in /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/image_sequence
# /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/image_sequence
# /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data
# [fold_A] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/A
# [fold_B] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/B
# [fold_AB] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB
# [num_imgs] =  1000000
# [use_AB] =  False
# [no_multiprocessing] =  False
# split = test, use 121/121 images
# split = test, number of images = 121
# Images ready to be processed
# AB folder placed in /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB
#  Your image dimensions are not divisible by 256; therefore your images have now been resized to: 1024
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS	[default: ./checkpoints]
#                 crop_size: 1024                          	[default: 256]
#                  dataroot: /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1                             	[default: 3]
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 1024                          	[default: 256]
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
#                      name: pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_256
#                       ngf: 64
#                no_dropout: True                          	[default: False]
#                   no_flip: False
#                      norm: batch
#                  num_test: 131                           	[default: 50]
#               num_threads: 4
#                 output_nc: 1                             	[default: 3]
#                     phase: test
#                preprocess: scale_width                   	[default: resize_and_crop]
#               results_dir: /media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/CHO-SYNCHRO-nuclei/20230504_630_day/Individual	[default: ./results/]
#            serial_batches: False
#                    suffix:
#                 use_wandb: False
#                   verbose: False
#        wandb_project_name: CycleGAN-and-pix2pix
# ----------------- End -------------------
# dataset [AlignedDataset] was created
# initialize network with normal
# model [Pix2PixModel] was created
# loading the model from /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 54.408 M
# -----------------------------------------------
# creating web directory /media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/CHO-SYNCHRO-nuclei/20230504_630_day/Individual/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024/test_latest
# processing (0000)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0000.png']
# processing (0005)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0005.png']
# processing (0010)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0010.png']
# processing (0015)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0015.png']
# processing (0020)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0020.png']
# processing (0025)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0025.png']
# processing (0030)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0030.png']
# processing (0035)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0035.png']
# processing (0040)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0040.png']
# processing (0045)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0045.png']
# processing (0050)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0050.png']
# processing (0055)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0055.png']
# processing (0060)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0060.png']
# processing (0065)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0065.png']
# processing (0070)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0070.png']
# processing (0075)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0075.png']
# processing (0080)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0080.png']
# processing (0085)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0085.png']
# processing (0090)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0090.png']
# processing (0095)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0095.png']
# processing (0100)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0100.png']
# processing (0105)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0105.png']
# processing (0110)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0110.png']
# processing (0115)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0115.png']
# processing (0120)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-03-P7-A01_0120.png']
# Images processed already
# CHO_day_630__live-02-Scene-04-P6-A01.czi
# ('CHO_day_630__live-02-Scene-04-P6-A01', '.czi') file loaded in python
# Images stored in /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/image_sequence
# /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/image_sequence
# /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data
# [fold_A] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/A
# [fold_B] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/B
# [fold_AB] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB
# [num_imgs] =  1000000
# [use_AB] =  False
# [no_multiprocessing] =  False
# split = test, use 121/121 images
# split = test, number of images = 121
# Images ready to be processed
# AB folder placed in /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB
#  Your image dimensions are not divisible by 256; therefore your images have now been resized to: 1024
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS	[default: ./checkpoints]
#                 crop_size: 1024                          	[default: 256]
#                  dataroot: /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1                             	[default: 3]
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 1024                          	[default: 256]
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
#                      name: pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_256
#                       ngf: 64
#                no_dropout: True                          	[default: False]
#                   no_flip: False
#                      norm: batch
#                  num_test: 131                           	[default: 50]
#               num_threads: 4
#                 output_nc: 1                             	[default: 3]
#                     phase: test
#                preprocess: scale_width                   	[default: resize_and_crop]
#               results_dir: /media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/CHO-SYNCHRO-nuclei/20230504_630_day/Individual	[default: ./results/]
#            serial_batches: False
#                    suffix:
#                 use_wandb: False
#                   verbose: False
#        wandb_project_name: CycleGAN-and-pix2pix
# ----------------- End -------------------
# dataset [AlignedDataset] was created
# initialize network with normal
# model [Pix2PixModel] was created
# loading the model from /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 54.408 M
# -----------------------------------------------
# creating web directory /media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/CHO-SYNCHRO-nuclei/20230504_630_day/Individual/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024/test_latest
# processing (0000)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0000.png']
# processing (0005)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0005.png']
# processing (0010)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0010.png']
# processing (0015)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0015.png']
# processing (0020)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0020.png']
# processing (0025)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0025.png']
# processing (0030)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0030.png']
# processing (0035)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0035.png']
# processing (0040)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0040.png']
# processing (0045)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0045.png']
# processing (0050)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0050.png']
# processing (0055)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0055.png']
# processing (0060)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0060.png']
# processing (0065)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0065.png']
# processing (0070)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0070.png']
# processing (0075)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0075.png']
# processing (0080)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0080.png']
# processing (0085)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0085.png']
# processing (0090)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0090.png']
# processing (0095)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0095.png']
# processing (0100)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0100.png']
# processing (0105)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0105.png']
# processing (0110)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0110.png']
# processing (0115)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0115.png']
# processing (0120)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-04-P6-A01_0120.png']
# Images processed already
# CHO_day_630__live-02-Scene-05-P10-A01.czi
# ('CHO_day_630__live-02-Scene-05-P10-A01', '.czi') file loaded in python
# Images stored in /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/image_sequence
# /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/image_sequence
# /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data
# [fold_A] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/A
# [fold_B] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/B
# [fold_AB] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB
# [num_imgs] =  1000000
# [use_AB] =  False
# [no_multiprocessing] =  False
# split = test, use 121/121 images
# split = test, number of images = 121
# Images ready to be processed
# AB folder placed in /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB
#  Your image dimensions are not divisible by 256; therefore your images have now been resized to: 1024
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS	[default: ./checkpoints]
#                 crop_size: 1024                          	[default: 256]
#                  dataroot: /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1                             	[default: 3]
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 1024                          	[default: 256]
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
#                      name: pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_256
#                       ngf: 64
#                no_dropout: True                          	[default: False]
#                   no_flip: False
#                      norm: batch
#                  num_test: 131                           	[default: 50]
#               num_threads: 4
#                 output_nc: 1                             	[default: 3]
#                     phase: test
#                preprocess: scale_width                   	[default: resize_and_crop]
#               results_dir: /media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/CHO-SYNCHRO-nuclei/20230504_630_day/Individual	[default: ./results/]
#            serial_batches: False
#                    suffix:
#                 use_wandb: False
#                   verbose: False
#        wandb_project_name: CycleGAN-and-pix2pix
# ----------------- End -------------------
# dataset [AlignedDataset] was created
# initialize network with normal
# model [Pix2PixModel] was created
# loading the model from /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 54.408 M
# -----------------------------------------------
# creating web directory /media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/CHO-SYNCHRO-nuclei/20230504_630_day/Individual/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024/test_latest
# processing (0000)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0000.png']
# processing (0005)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0005.png']
# processing (0010)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0010.png']
# processing (0015)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0015.png']
# processing (0020)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0020.png']
# processing (0025)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0025.png']
# processing (0030)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0030.png']
# processing (0035)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0035.png']
# processing (0040)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0040.png']
# processing (0045)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0045.png']
# processing (0050)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0050.png']
# processing (0055)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0055.png']
# processing (0060)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0060.png']
# processing (0065)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0065.png']
# processing (0070)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0070.png']
# processing (0075)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0075.png']
# processing (0080)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0080.png']
# processing (0085)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0085.png']
# processing (0090)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0090.png']
# processing (0095)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0095.png']
# processing (0100)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0100.png']
# processing (0105)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0105.png']
# processing (0110)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0110.png']
# processing (0115)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0115.png']
# processing (0120)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/CHO_day_630__live-02-Scene-05-P10-A01_0120.png']
# Images processed already
# CHO_day_630__live-02-Scene-06-P5-A01.czi
# ('CHO_day_630__live-02-Scene-06-P5-A01', '.czi') file loaded in python
# Images stored in /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/image_sequence
# /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/image_sequence
# /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data
# [fold_A] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/A
# [fold_B] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/B
# [fold_AB] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB
# [num_imgs] =  1000000
# [use_AB] =  False
# [no_multiprocessing] =  False
# split = test, use 121/121 images
# split = test, number of images = 121
# Images ready to be processed
# AB folder placed in /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB
# ...
# CHO_day_475-live-01-Scene-38-P7-A04 processed
# CHO_day_475-live-01-Scene-39-P6-A04 processed
# CHO_day_475-live-01-Scene-40-P10-A04 processed
# CHO_day_475-live-01-Scene-41-P8-B04 processed
# CHO_day_475-live-01-Scene-42-P3-B04 processed
# CHO_day_475-live-01-Scene-43-P7-B04 processed
# CHO_day_475-live-01-Scene-44-P2-B04 processed
# CHO_day_475-live-01-Scene-45-P6-B04 processed
# CHO_day_475-live-01-Scene-46-P5-B04 processed
# CHO_day_475-live-01-Scene-47-P9-B04 processed
# CHO_day_475-live-01-Scene-48-P1-B04 processed
# CHO_day_475-live-01-Scene-49-P4-B04 processed
# CHO_day_475-live-01-Scene-50-P10-B04 processed
# CHO_day_475-live-01-Scene-51-P5-B03 processed
# CHO_day_475-live-01-Scene-52-P4-B03 processed
O_20x_live-01-Scene-55-P7-B03.tif', 'CHO_20x_live-01-Scene-56-P2-B03.tif', 'CHO_20x_live-01-Scene-58-P3-B03.tif', 'CHO_20x_live-01-Scene-59-P5-B03.tif', 'CHO_20x_live-01-Scene-63-P6-B02.tif', 'CHO_20x_live-01-Scene-64-P4-B02.tif', 'CHO_20x_live-01-Scene-66-P7-B02.tif', 'CHO_20x_live-01-Scene-68-P9-B02.tif', 'CHO_20x_live-01-Scene-70-P10-B02.tif', 'CHO_20x_live-01-Scene-71-P1-B01.tif', 'CHO_20x_live-01-Scene-73-P10-B01.tif', 'CHO_20x_live-01-Scene-75-P6-B01.tif', 'CHO_20x_live-01-Scene-76-P9-B01.tif', 'CHO_20x_live-01-Scene-78-P4-B01.tif', 'CHO_20x_live-01-Scene-79-P7-B01.tif', 'CHO_20x_live-01-Scene-80-P8-B01.tif']
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[3], line 21
#      13 process_pix2pix(path2data, pix2pix_model_path, Result_folder, pix2pix_code_dir, pix2pix_working_directory, checkpoint="latest", normalisation="Contrast stretching", nc=1)
#      15 #path2data = "/home/ocb/HardDrive_4TB/EGM/PHX/DATA/RAW"
#      16 #process_pix2pix(path2data, pix2pix_model_path, Result_folder, pix2pix_code_dir, pix2pix_working_directory, checkpoint="latest", normalisation="Contrast stretching", nc=1)
#      17
#      18 #path2data = "/media/ocb/OCB-Data 1/Phototoxicity/ITQB/Individual"
#      19 #process_pix2pix(path2data, pix2pix_model_path, Result_folder, pix2pix_code_dir, pix2pix_working_directory, checkpoint="latest", normalisation="Contrast stretching", nc=1)
# ---> 21 digest_predictions(Result_folder)
#
# Cell In[2], line 257, in digest_predictions(Result_folder)
#     255 for f in folders:
#     256     if f[0] != '.':
# --> 257         digest_predictions(os.path.join(Result_folder, f))
#
# Cell In[2], line 257, in digest_predictions(Result_folder)
#     255 for f in folders:
#     256     if f[0] != '.':
# --> 257         digest_predictions(os.path.join(Result_folder, f))
#
# Cell In[2], line 257, in digest_predictions(Result_folder)
#     255 for f in folders:
#     256     if f[0] != '.':
# --> 257         digest_predictions(os.path.join(Result_folder, f))
#
# Cell In[2], line 249, in digest_predictions(Result_folder)
#     248 def digest_predictions(Result_folder):
# --> 249     folders = os.listdir(Result_folder)
#     250     folders.sort
#     251     print(folders)
#
# NotADirectoryError: [Errno 20] Not a directory: '/media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/CHO-SYNCHRO-nuclei/2022-07-26/videos_fake_B/CHO_20x_live-01-Scene-02-P10-A01.tif'

# %%
Result_folder = "/media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/CHO-SYNCHRO-nuclei/missing/"
digest_predictions(Result_folder)
# Out:
# ['20230503_475_night', '20230504_568_night_630-rename', '20230505_475_day', '20230504_630_day']
# ['Individual']
# ['pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024']
# ['test_latest']
# ['index.html', 'images_fake_B', 'images_real_A']
# /tmp/ipykernel_31103/1761352285.py:183: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   imsave(os.path.join(path2real_reconstructions, f"{v}.tif"), real_video)
# /tmp/ipykernel_31103/1761352285.py:184: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   imsave(os.path.join(path2fake_reconstructions, f"{v}.tif"), fake_video)
# CHO_day_475__live-02-Scene-01-P3-A01 processed
# CHO_day_475__live-02-Scene-02-P1-A01 processed
# CHO_day_475__live-02-Scene-03-P8-A01 processed
# CHO_day_475__live-02-Scene-04-P7-A01 processed
# CHO_day_475__live-02-Scene-05-P6-A01 processed
# CHO_day_475__live-02-Scene-06-P2-A01 processed
# CHO_day_475__live-02-Scene-07-P10-A01 processed
# CHO_day_630__live-02-Scene-44-P7-B04 processed
# CHO_day_630__live-02-Scene-45-P9-B04 processed
# CHO_day_630__live-02-Scene-46-P10-B04 processed
# CHO_day_630__live-02-Scene-47-P2-B04 processed
# CHO_day_630__live-02-Scene-48-P5-B04 processed
# CHO_day_630__live-02-Scene-49-P8-B04 processed
# CHO_day_630__live-02-Scene-50-P1-B04 processed
# CHO_day_630__live-02-Scene-51-P4-B03 processed
# CHO_day_630__live-02-Scene-52-P7-B03 processed
# CHO_day_630__live-02-Scene-53-P3-B03 processed
# CHO_day_630__live-02-Scene-54-P8-B03 processed
# CHO_day_630__live-02-Scene-55-P6-B03 processed
# CHO_day_630__live-02-Scene-56-P2-B03 processed
# CHO_day_630__live-02-Scene-57-P5-B03 processed
# CHO_day_630__live-02-Scene-58-P10-B03 processed
# CHO_day_630__live-02-Scene-59-P1-B03 processed
# CHO_day_630__live-02-Scene-60-P9-B03 processed
# CHO_day_630__live-02-Scene-61-P4-B02 processed
# CHO_day_630__live-02-Scene-62-P5-B02 processed
# CHO_day_630__live-02-Scene-63-P1-B02 processed
# CHO_day_630__live-02-Scene-64-P3-B02 processed
# CHO_day_630__live-02-Scene-65-P6-B02 processed
# CHO_day_630__live-02-Scene-66-P7-B02 processed
# CHO_day_630__live-02-Scene-67-P2-B02 processed
# CHO_day_630__live-02-Scene-68-P9-B02 processed
# CHO_day_630__live-02-Scene-69-P8-B02 processed
# CHO_day_630__live-02-Scene-70-P10-B02 processed
# CHO_day_630__live-02-Scene-71-P1-B01 processed
# CHO_day_630__live-02-Scene-72-P7-B01 processed
# CHO_day_630__live-02-Scene-73-P3-B01 processed
# CHO_day_630__live-02-Scene-74-P5-B01 processed
# CHO_day_630__live-02-Scene-75-P4-B01 processed
# CHO_day_630__live-02-Scene-76-P2-B01 processed
# CHO_day_630__live-02-Scene-77-P9-B01 processed
# CHO_day_630__live-02-Scene-78-P8-B01 processed
# CHO_day_630__live-02-Scene-79-P10-B01 processed
# CHO_day_630__live-02-Scene-80-P6-B01 processed

# %%
#Here, we install libraries which are not already included in Colab.
#!git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
import os
pix2pix_working_directory = "/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/"
pix2pix_code_dir = "/home/ocb/HardDrive_4TB/EGM/PHX/PhotoFITT/notebooks/deep-learning/pix2pix/"
#Result_folder = "/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/RESULTS/PHX_DATA"
Result_folder = "/media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/CHO-SYNCHRO-nuclei"

pix2pix_model_path = "/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024"
#pix2pix_model_path = "/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/pix2pix_hela_selectedz_nuclei_ph_norm_contrast_resized1024_18042024/"

path2data = "/media/ocb/OCB-Data2/PhotoFiTT/RAW DATA/CHO-SYNCHRO"
process_pix2pix(path2data, pix2pix_model_path, Result_folder, pix2pix_code_dir, pix2pix_working_directory, checkpoint="latest", normalisation="Contrast stretching", nc=1)

#path2data = "/home/ocb/HardDrive_4TB/EGM/PHX/DATA/RAW"
#process_pix2pix(path2data, pix2pix_model_path, Result_folder, pix2pix_code_dir, pix2pix_working_directory, checkpoint="latest", normalisation="Contrast stretching", nc=1)

#path2data = "/media/ocb/OCB-Data 1/Phototoxicity/ITQB/Individual"
#process_pix2pix(path2data, pix2pix_model_path, Result_folder, pix2pix_code_dir, pix2pix_working_directory, checkpoint="latest", normalisation="Contrast stretching", nc=1)

digest_predictions(Result_folder)

# %%
Result_folder = "/media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/CHO-SYNCHRO-nuclei"
digest_predictions(Result_folder)
