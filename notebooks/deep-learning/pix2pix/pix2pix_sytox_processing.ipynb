# %%
import sys
sys.path.append("/home/ocb/HardDrive_4TB/EGM/PHX/PhotoFITT/photofitt/")
from utils.normalisation import normalise_phc_timelapse
import tifffile
from tifffile import imsave
import os
import numpy as np
import cv2
import czifile as zis
import shutil
from skimage import io
from skimage import exposure


def normalise_data(Source_QC_folder, Target_QC_folder, Normalisation_QC_source, Normalisation_QC_target, Im_path):
    if Normalisation_QC_source == "Contrast stretching":

        for filename in os.listdir(Source_QC_folder):

            img = io.imread(os.path.join(Source_QC_folder,filename)).astype(np.float32)
            short_name = os.path.splitext(filename)

            p2, p99 = np.percentile(img, (1., 99.9))
            img = exposure.rescale_intensity(img, in_range=(p2, p99))

            img = 255 * img # Now scale by 255
            img = img.astype(np.uint8)
            cv2.imwrite(os.path.join(Im_path, "A", "test", f"{short_name[0]}.png"), img)

    if Normalisation_QC_target == "Contrast stretching":
        for filename in os.listdir(Target_QC_folder):

            img = io.imread(os.path.join(Target_QC_folder,filename)).astype(np.float32)
            short_name = os.path.splitext(filename)

            p2, p99 = np.percentile(img, (1., 99.9))
            img = exposure.rescale_intensity(img, in_range=(p2, p99))

            img = 255 * img # Now scale by 255
            img = img.astype(np.uint8)
            cv2.imwrite(os.path.join(Im_path, "B", "test", f"{short_name[0]}.png"), img)

    if Normalisation_QC_source == "Adaptive Equalization":
        for filename in os.listdir(Source_QC_folder):

            img = io.imread(os.path.join(Source_QC_folder,filename))
            short_name = os.path.splitext(filename)

            img = exposure.equalize_adapthist(img, clip_limit=0.03)

            img = 255 * img # Now scale by 255
            img = img.astype(np.uint8)
            cv2.imwrite(os.path.join(Im_path, "A", "test", f"{short_name[0]}.png"), img)


    if Normalisation_QC_target == "Adaptive Equalization":
        for filename in os.listdir(Target_QC_folder):

            img = io.imread(os.path.join(Target_QC_folder,filename))
            short_name = os.path.splitext(filename)

            img = exposure.equalize_adapthist(img, clip_limit=0.03)

            img = 255 * img # Now scale by 255
            img = img.astype(np.uint8)
            cv2.imwrite(os.path.join(Im_path, "B", "test", f"{short_name[0]}.png"), img)

    if Normalisation_QC_source == "None":
        for filename in os.listdir(Source_QC_folder):
            img = io.imread(os.path.join(Source_QC_folder,filename))
            short_name = os.path.splitext(filename)
            cv2.imwrite(os.path.join(Im_path, "A", "test", f"{short_name[0]}.png"), img)
            
    if Normalisation_QC_target == "None":
        for filename in os.listdir(Target_QC_folder):
            img = io.imread(os.path.join(Target_QC_folder,filename))
            short_name = os.path.splitext(filename)
            cv2.imwrite(os.path.join(Im_path, "B", "test", f"{short_name[0]}.png"), img)

def stack2im(path2stack, path2im, ph_normalisation=False, multichannel=False, ch=0):
    if path2stack.endswith(".czi"):
        f = zis.CziFile(path2stack)
        stack = f.asarray()
    elif path2stack.__contains__(".tif"):
        stack = tifffile.imread(path2stack)
    else:
        print(f"{path2stack} format not compatible")
    stack = stack.squeeze()
    if multichannel:
        stack = stack[:,ch]
    file_name = os.path.basename(path2stack)
    file_name = os.path.splitext(file_name)
    print(f"{file_name} file loaded in python")
    os.makedirs(path2im, exist_ok=True)
    for t in range(len(stack)):
        if ph_normalisation:
            im = normalise_phc_timelapse(stack[t], keep_mean=False)
            # note that images are float 32 with negative values
            im = (im-np.min(im))/(np.max(im) - np.min(im))
        else:
            im = stack[t]
        cv2.imwrite(os.path.join(path2im, f"{file_name[0]}_{t:04d}.tif"), im)
    #Find image XY dimension
    Image_Y = im.shape[0]
    Image_X = im.shape[1]
    return min(Image_Y, Image_X)
    


def prepare_im_sequence(path2im, working_dir, pix2pix_code_dir, normalisation="Contrast stretching"):
    
    # Here we need to move the data to be analysed so that pix2pix can find them
    Saving_path_prediction= working_dir
    
    if os.path.exists(Saving_path_prediction):
        shutil.rmtree(Saving_path_prediction)
    os.makedirs(Saving_path_prediction, exist_ok=True)
    
    imageA_folder = os.path.join(Saving_path_prediction, "A")
    os.makedirs(imageA_folder, exist_ok=True)
    
    imageB_folder = os.path.join(Saving_path_prediction, "B")
    os.makedirs(imageB_folder, exist_ok=True)
    
    imageAB_folder = os.path.join(Saving_path_prediction, "AB")
    os.makedirs(imageAB_folder, exist_ok=True)
    
    testAB_Folder = os.path.join(imageAB_folder, "test")
    os.makedirs(testAB_Folder, exist_ok=True)
    
    testA_Folder = os.path.join(imageA_folder, "test")
    os.makedirs(testA_Folder, exist_ok=True)
    
    testB_Folder = os.path.join(imageB_folder, "test")
    os.makedirs(testB_Folder, exist_ok=True)
    
    # Normalise the image sequence with the pix2pix normalisation
    print(path2im)
    print(Saving_path_prediction)
    normalise_data(path2im, path2im, normalisation, normalisation, Saving_path_prediction)

    # Process normalised data for pix2pix to process it
    os.chdir(pix2pix_code_dir)
    # !python3 pytorch-CycleGAN-and-pix2pix/datasets/combine_A_and_B.py --fold_A "$imageA_folder" --fold_B "$imageB_folder" --fold_AB "$imageAB_folder"
    print("Images ready to be processed")
    print(f'AB folder placed in {imageAB_folder}')
    
    return imageAB_folder
    
def process_im_sequence(pix2pix_code_dir, imageAB_folder, Prediction_model_name, Prediction_model_path, Result_folder, Nb_files_Data_folder, patch_size=1024, checkpoint="latest", nc=1):
    
    if not patch_size % 256 == 0:
      patch_size = ((int(patch_size / 256)) * 256)
      print (" Your image dimensions are not divisible by 256; therefore your images have now been resized to:",patch_size)
    
    if patch_size < 256:
      patch_size = 256

    print("Chosen image size to process: ", patch_size)
    os.chdir(pix2pix_code_dir)
    # !python3 pytorch-CycleGAN-and-pix2pix/test.py --dataroot "$imageAB_folder" --name "$Prediction_model_name" --model pix2pix --no_dropout --preprocess scale_width --load_size $patch_size --crop_size $patch_size --results_dir "$Result_folder" --checkpoints_dir "$Prediction_model_path" --num_test $Nb_files_Data_folder --epoch $checkpoint --input_nc "$nc" --output_nc "$nc" --dataset_mode "aligned"
    print("Images processed already")


def frames2videos_pix2pix(path2im):
    path2real = os.path.join(path2im, "images_real_A")
    path2fake = os.path.join(path2im, "images_fake_B")
    
    files = os.listdir(path2real)
    
    video_names = [i.split("_0000_")[0] for i in files if i.__contains__("_0000_")]
    
    path2real_reconstructions = os.path.join(path2im, "videos_real_A")
    path2fake_reconstructions = os.path.join(path2im, "videos_fake_B")
    os.makedirs(path2real_reconstructions, exist_ok=True)
    os.makedirs(path2fake_reconstructions, exist_ok=True)
    for v in video_names:
        video = [j for j in files if j.__contains__(v)]
        video.sort()
        real_video = []
        fake_video = []
        
        for j in video:
            real_video.append(cv2.imread(os.path.join(path2real, j))[...,0])
            fake_filename = j.split("_real_A.png")[0] + "_fake_B.png"
            
            fake_video.append(cv2.imread(os.path.join(path2fake, fake_filename))[...,0])
        real_video = np.array(real_video)
        fake_video = np.array(fake_video)
        imsave(os.path.join(path2real_reconstructions, f"{v}.tif"), real_video)
        imsave(os.path.join(path2fake_reconstructions, f"{v}.tif"), fake_video)
        print(f"{v} processed")
        
def process_pix2pix(path2data, pix2pix_model_path, Result_folder, pix2pix_code_dir, working_dir, checkpoint="latest", normalisation="Contrast stretching", nc=1, multichannel=False, ch=0, patch_size=None):
    folders = os.listdir(path2data)
    folders.sort
    print(folders)
    os.makedirs(Result_folder, exist_ok=True)
    path2imsequence = os.path.join(working_dir, "image_sequence")
    Prediction_model_name = os.path.basename(pix2pix_model_path)
    Prediction_model_path = os.path.dirname(pix2pix_model_path)

    if os.path.exists(path2imsequence):
        shutil.rmtree(path2imsequence)
    
    for i in range(len(folders)):
        f = folders[i]
        if f[0] != '.':
            if not f.__contains__('.'):

                process_pix2pix(os.path.join(path2data, f), pix2pix_model_path, os.path.join(Result_folder, f), 
                                pix2pix_code_dir, working_dir, checkpoint=checkpoint, 
                                normalisation=normalisation, nc=nc, patch_size=patch_size)
            elif f.__contains__('.czi') or f.__contains__('.tif'):
                print(f)
                # Convert the CZI stack into a normalised image sequence and save it in a general folder.
                patch_size_real = stack2im(os.path.join(path2data, f), path2imsequence, ph_normalisation=True, multichannel=multichannel, ch=ch)
                if patch_size is not None:
                    patch_size_real = patch_size
                print(f'Images stored in {path2imsequence}')
            
                imageAB_folder = prepare_im_sequence(path2imsequence, os.path.join(working_dir, "prepared_data"), pix2pix_code_dir, normalisation=normalisation)
                
                Nb_files_Data_folder = len(os.listdir(os.path.join(imageAB_folder, "test")))+10
                
                process_im_sequence(pix2pix_code_dir, imageAB_folder, Prediction_model_name, Prediction_model_path,
                                    Result_folder, Nb_files_Data_folder, patch_size=patch_size_real, checkpoint=checkpoint, nc=nc)

                Checkpoint_name = "test_"+str(checkpoint)

                
                Prediction_results_folder = os.path.join(Result_folder, Prediction_model_name, Checkpoint_name, "images")
                
                Prediction_results_images = os.listdir(Prediction_results_folder)
                
                for f in Prediction_results_images:
                  if (f.endswith("_real_B.png")):
                    os.remove(Prediction_results_folder+"/"+f)
                
                
                os.makedirs(os.path.join(Prediction_results_folder + "_fake_B"),exist_ok=True)
                os.makedirs(os.path.join(Prediction_results_folder + "_real_A"),exist_ok=True)
                
                for f in os.listdir(Prediction_results_folder):
                    if f.endswith("fake_B.png"):
                        shutil.copy(os.path.join(Prediction_results_folder, f),
                                    os.path.join(Prediction_results_folder + "_fake_B", f))
                    elif f.endswith("real_A.png"):
                        shutil.copy(os.path.join(Prediction_results_folder, f),
                                    os.path.join(Prediction_results_folder + "_real_A", f))
                # Remove the images
                shutil.rmtree(Prediction_results_folder)

                if os.path.exists(path2imsequence):
                    shutil.rmtree(path2imsequence)

def digest_predictions(Result_folder):
    folders = os.listdir(Result_folder)
    folders.sort
    print(folders)
    if "images_fake_B" in folders:
        frames2videos_pix2pix(Result_folder)
    else:
        for f in folders:
            if f[0] != '.':
                digest_predictions(os.path.join(Result_folder, f))


print("All functions loaded")
# Out:
# All functions loaded

# %%
Result_folder = "/media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/SYTOX_NIKON1"
digest_predictions(Result_folder)
# Out:
# ['pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024']
# ['test_latest']
# ['index.html', 'images_fake_B', 'images_real_A']
# /tmp/ipykernel_310378/3749622943.py:190: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   imsave(os.path.join(path2real_reconstructions, f"{v}.tif"), real_video)
# /tmp/ipykernel_310378/3749622943.py:191: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   imsave(os.path.join(path2fake_reconstructions, f"{v}.tif"), fake_video)
# cho_sync_unsync_sytox_live_Sync_C4 processed
# cho_sync_unsync_sytox_live_Sync_C5 processed
# cho_sync_unsync_sytox_live_Unsync_100ms1 processed
# cho_sync_unsync_sytox_live_Unsync_100ms2 processed
# cho_sync_unsync_sytox_live_Unsync_100ms3 processed
# cho_sync_unsync_sytox_live_Unsync_100ms4 processed
# cho_sync_unsync_sytox_live_Unsync_100ms5 processed
# cho_sync_unsync_sytox_live_Unsync_10s1 processed
# cho_sync_unsync_sytox_live_Unsync_10s2 processed
# cho_sync_unsync_sytox_live_Unsync_10s3 processed
# cho_sync_unsync_sytox_live_Unsync_10s4 processed

# %%
# !ls /media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/
# Out:
# 20230629_unsync_UV_day	   20230706_unsync_UV_day    SYTOX
# 20230704_unsync_475_night  20230706_unsync_UV_night  SYTOX_NIKON
# 20230705_unsync_630_day    CHO-SYNCHRO		     SYTOX_NIKON1
# 20230705_unsync_630_night  CHO-UNSYNCHRO

# %%
#Here, we install libraries which are not already included in Colab.
#!git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
import os
pix2pix_working_directory = "/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/"
pix2pix_code_dir = "/home/ocb/HardDrive_4TB/EGM/PHX/PhotoFITT/notebooks/deep-learning/pix2pix/"
Result_folder = "/media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/SYTOX_NIKON1"
pix2pix_model_path = "/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024"
path2data = "/media/ocb/OCB-Data2/PhotoFiTT/RAW DATA/SYTOX/SYTOX-NikonTI-2/DIC"
process_pix2pix(path2data,
                pix2pix_model_path,
                Result_folder,
                pix2pix_code_dir,
                pix2pix_working_directory,
                checkpoint="latest",
                normalisation="Contrast stretching",
                nc=1,
                multichannel=False, 
                patch_size=1024)

digest_predictions(Result_folder)
# Out:
# ['cho_sync_unsync_sytox_live_Unsync_10s4.tif', 'cho_sync_unsync_sytox_live_Unsync_10s5.tif', 'cho_sync_unsync_sytox_live_Unsync_1s1.tif', 'cho_sync_unsync_sytox_live_Unsync_1s2.tif', 'cho_sync_unsync_sytox_live_Unsync_1s3.tif', 'cho_sync_unsync_sytox_live_Unsync_1s4.tif', 'cho_sync_unsync_sytox_live_Unsync_1s5.tif', 'cho_sync_unsync_sytox_live_Unsync_C1.tif', 'cho_sync_unsync_sytox_live_Unsync_C2.tif', 'cho_sync_unsync_sytox_live_Unsync_C3.tif', 'cho_sync_unsync_sytox_live_Unsync_C4.tif', 'cho_sync_unsync_sytox_live_Unsync_C5.tif']
# cho_sync_unsync_sytox_live_Unsync_10s4.tif
# ('cho_sync_unsync_sytox_live_Unsync_10s4', '.tif') file loaded in python
# Images stored in /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/image_sequence
# /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/image_sequence
# /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data
# [fold_A] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/A
# [fold_B] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/B
# [fold_AB] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB
# [num_imgs] =  1000000
# [use_AB] =  False
# [no_multiprocessing] =  False
# split = test, use 181/181 images
# split = test, number of images = 181
# Images ready to be processed
# AB folder placed in /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB
# Chosen image size to process:  1024
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS	[default: ./checkpoints]
#                 crop_size: 1024                          	[default: 256]
#                  dataroot: /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1                             	[default: 3]
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 1024                          	[default: 256]
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
#                      name: pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_256
#                       ngf: 64
#                no_dropout: True                          	[default: False]
#                   no_flip: False
#                      norm: batch
#                  num_test: 191                           	[default: 50]
#               num_threads: 4
#                 output_nc: 1                             	[default: 3]
#                     phase: test
#                preprocess: scale_width                   	[default: resize_and_crop]
#               results_dir: /media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/SYTOX_NIKON1	[default: ./results/]
#            serial_batches: False
#                    suffix:
#                 use_wandb: False
#                   verbose: False
#        wandb_project_name: CycleGAN-and-pix2pix
# ----------------- End -------------------
# dataset [AlignedDataset] was created
# initialize network with normal
# model [Pix2PixModel] was created
# loading the model from /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 54.408 M
# -----------------------------------------------
# creating web directory /media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/SYTOX_NIKON1/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024/test_latest
# processing (0000)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0000.png']
# processing (0005)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0005.png']
# processing (0010)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0010.png']
# processing (0015)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0015.png']
# processing (0020)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0020.png']
# processing (0025)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0025.png']
# processing (0030)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0030.png']
# processing (0035)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0035.png']
# processing (0040)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0040.png']
# processing (0045)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0045.png']
# processing (0050)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0050.png']
# processing (0055)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0055.png']
# processing (0060)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0060.png']
# processing (0065)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0065.png']
# processing (0070)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0070.png']
# processing (0075)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0075.png']
# processing (0080)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0080.png']
# processing (0085)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0085.png']
# processing (0090)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0090.png']
# processing (0095)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0095.png']
# processing (0100)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0100.png']
# processing (0105)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0105.png']
# processing (0110)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0110.png']
# processing (0115)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0115.png']
# processing (0120)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0120.png']
# processing (0125)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0125.png']
# processing (0130)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0130.png']
# processing (0135)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0135.png']
# processing (0140)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0140.png']
# processing (0145)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0145.png']
# processing (0150)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0150.png']
# processing (0155)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0155.png']
# processing (0160)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0160.png']
# processing (0165)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0165.png']
# processing (0170)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0170.png']
# processing (0175)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0175.png']
# processing (0180)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s4_0180.png']
# Images processed already
# cho_sync_unsync_sytox_live_Unsync_10s5.tif
# ('cho_sync_unsync_sytox_live_Unsync_10s5', '.tif') file loaded in python
# Images stored in /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/image_sequence
# /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/image_sequence
# /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data
# [fold_A] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/A
# [fold_B] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/B
# [fold_AB] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB
# [num_imgs] =  1000000
# [use_AB] =  False
# [no_multiprocessing] =  False
# split = test, use 181/181 images
# split = test, number of images = 181
# Images ready to be processed
# AB folder placed in /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB
# Chosen image size to process:  1024
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS	[default: ./checkpoints]
#                 crop_size: 1024                          	[default: 256]
#                  dataroot: /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1                             	[default: 3]
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 1024                          	[default: 256]
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
#                      name: pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_256
#                       ngf: 64
#                no_dropout: True                          	[default: False]
#                   no_flip: False
#                      norm: batch
#                  num_test: 191                           	[default: 50]
#               num_threads: 4
#                 output_nc: 1                             	[default: 3]
#                     phase: test
#                preprocess: scale_width                   	[default: resize_and_crop]
#               results_dir: /media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/SYTOX_NIKON1	[default: ./results/]
#            serial_batches: False
#                    suffix:
#                 use_wandb: False
#                   verbose: False
#        wandb_project_name: CycleGAN-and-pix2pix
# ----------------- End -------------------
# dataset [AlignedDataset] was created
# initialize network with normal
# model [Pix2PixModel] was created
# loading the model from /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 54.408 M
# -----------------------------------------------
# creating web directory /media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/SYTOX_NIKON1/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024/test_latest
# processing (0000)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0000.png']
# processing (0005)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0005.png']
# processing (0010)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0010.png']
# processing (0015)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0015.png']
# processing (0020)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0020.png']
# processing (0025)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0025.png']
# processing (0030)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0030.png']
# processing (0035)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0035.png']
# processing (0040)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0040.png']
# processing (0045)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0045.png']
# processing (0050)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0050.png']
# processing (0055)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0055.png']
# processing (0060)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0060.png']
# processing (0065)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0065.png']
# processing (0070)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0070.png']
# processing (0075)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0075.png']
# processing (0080)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0080.png']
# processing (0085)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0085.png']
# processing (0090)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0090.png']
# processing (0095)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0095.png']
# processing (0100)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0100.png']
# processing (0105)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0105.png']
# processing (0110)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0110.png']
# processing (0115)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0115.png']
# processing (0120)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0120.png']
# processing (0125)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0125.png']
# processing (0130)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0130.png']
# processing (0135)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0135.png']
# processing (0140)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0140.png']
# processing (0145)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0145.png']
# processing (0150)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0150.png']
# processing (0155)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0155.png']
# processing (0160)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0160.png']
# processing (0165)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0165.png']
# processing (0170)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0170.png']
# processing (0175)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0175.png']
# processing (0180)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_10s5_0180.png']
# Images processed already
# cho_sync_unsync_sytox_live_Unsync_1s1.tif
# ('cho_sync_unsync_sytox_live_Unsync_1s1', '.tif') file loaded in python
# Images stored in /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/image_sequence
# /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/image_sequence
# /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data
# [fold_A] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/A
# [fold_B] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/B
# [fold_AB] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB
# [num_imgs] =  1000000
# [use_AB] =  False
# [no_multiprocessing] =  False
# split = test, use 181/181 images
# split = test, number of images = 181
# Images ready to be processed
# AB folder placed in /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB
# Chosen image size to process:  1024
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS	[default: ./checkpoints]
#                 crop_size: 1024                          	[default: 256]
#                  dataroot: /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1                             	[default: 3]
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 1024                          	[default: 256]
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
#                      name: pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_256
#                       ngf: 64
#                no_dropout: True                          	[default: False]
#                   no_flip: False
#                      norm: batch
#                  num_test: 191                           	[default: 50]
#               num_threads: 4
#                 output_nc: 1                             	[default: 3]
#                     phase: test
#                preprocess: scale_width                   	[default: resize_and_crop]
#               results_dir: /media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/SYTOX_NIKON1	[default: ./results/]
#            serial_batches: False
#                    suffix:
#                 use_wandb: False
#                   verbose: False
#        wandb_project_name: CycleGAN-and-pix2pix
# ----------------- End -------------------
# dataset [AlignedDataset] was created
# initialize network with normal
# model [Pix2PixModel] was created
# loading the model from /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 54.408 M
# -----------------------------------------------
# creating web directory /media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/SYTOX_NIKON1/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024/test_latest
# processing (0000)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0000.png']
# processing (0005)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0005.png']
# processing (0010)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0010.png']
# processing (0015)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0015.png']
# processing (0020)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0020.png']
# processing (0025)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0025.png']
# processing (0030)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0030.png']
# processing (0035)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0035.png']
# processing (0040)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0040.png']
# processing (0045)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0045.png']
# processing (0050)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0050.png']
# processing (0055)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0055.png']
# processing (0060)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0060.png']
# processing (0065)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0065.png']
# processing (0070)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0070.png']
# processing (0075)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0075.png']
# processing (0080)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0080.png']
# processing (0085)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0085.png']
# processing (0090)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0090.png']
# processing (0095)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0095.png']
# processing (0100)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0100.png']
# processing (0105)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0105.png']
# processing (0110)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0110.png']
# processing (0115)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0115.png']
# processing (0120)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0120.png']
# processing (0125)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0125.png']
# processing (0130)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0130.png']
# processing (0135)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0135.png']
# processing (0140)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0140.png']
# processing (0145)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0145.png']
# processing (0150)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0150.png']
# processing (0155)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0155.png']
# processing (0160)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0160.png']
# processing (0165)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0165.png']
# processing (0170)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0170.png']
# processing (0175)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0175.png']
# processing (0180)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s1_0180.png']
# Images processed already
# cho_sync_unsync_sytox_live_Unsync_1s2.tif
# ('cho_sync_unsync_sytox_live_Unsync_1s2', '.tif') file loaded in python
# Images stored in /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/image_sequence
# /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/image_sequence
# /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data
# [fold_A] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/A
# [fold_B] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/B
# [fold_AB] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB
# [num_imgs] =  1000000
# [use_AB] =  False
# [no_multiprocessing] =  False
# split = test, use 181/181 images
# split = test, number of images = 181
# Images ready to be processed
# AB folder placed in /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB
# Chosen image size to process:  1024
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS	[default: ./checkpoints]
#                 crop_size: 1024                          	[default: 256]
#                  dataroot: /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1                             	[default: 3]
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 1024                          	[default: 256]
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
#                      name: pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_256
#                       ngf: 64
#                no_dropout: True                          	[default: False]
#                   no_flip: False
#                      norm: batch
#                  num_test: 191                           	[default: 50]
#               num_threads: 4
#                 output_nc: 1                             	[default: 3]
#                     phase: test
#                preprocess: scale_width                   	[default: resize_and_crop]
#               results_dir: /media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/SYTOX_NIKON1	[default: ./results/]
#            serial_batches: False
#                    suffix:
#                 use_wandb: False
#                   verbose: False
#        wandb_project_name: CycleGAN-and-pix2pix
# ----------------- End -------------------
# dataset [AlignedDataset] was created
# initialize network with normal
# model [Pix2PixModel] was created
# loading the model from /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 54.408 M
# -----------------------------------------------
# creating web directory /media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/SYTOX_NIKON1/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024/test_latest
# processing (0000)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0000.png']
# processing (0005)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0005.png']
# processing (0010)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0010.png']
# processing (0015)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0015.png']
# processing (0020)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0020.png']
# processing (0025)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0025.png']
# processing (0030)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0030.png']
# processing (0035)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0035.png']
# processing (0040)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0040.png']
# processing (0045)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0045.png']
# processing (0050)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0050.png']
# processing (0055)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0055.png']
# processing (0060)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0060.png']
# processing (0065)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0065.png']
# processing (0070)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0070.png']
# processing (0075)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0075.png']
# processing (0080)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0080.png']
# processing (0085)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0085.png']
# processing (0090)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0090.png']
# processing (0095)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0095.png']
# processing (0100)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0100.png']
# processing (0105)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0105.png']
# processing (0110)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0110.png']
# processing (0115)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0115.png']
# processing (0120)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0120.png']
# processing (0125)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0125.png']
# processing (0130)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0130.png']
# processing (0135)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0135.png']
# processing (0140)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0140.png']
# processing (0145)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0145.png']
# processing (0150)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0150.png']
# processing (0155)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0155.png']
# processing (0160)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0160.png']
# processing (0165)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0165.png']
# processing (0170)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0170.png']
# processing (0175)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0175.png']
# processing (0180)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s2_0180.png']
# Images processed already
# cho_sync_unsync_sytox_live_Unsync_1s3.tif
# ('cho_sync_unsync_sytox_live_Unsync_1s3', '.tif') file loaded in python
# Images stored in /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/image_sequence
# /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/image_sequence
# /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data
# [fold_A] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/A
# [fold_B] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/B
# [fold_AB] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB
# [num_imgs] =  1000000
# [use_AB] =  False
# [no_multiprocessing] =  False
# split = test, use 181/181 images
# split = test, number of images = 181
# Images ready to be processed
# AB folder placed in /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB
# Chosen image size to process:  1024
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS	[default: ./checkpoints]
#                 crop_size: 1024                          	[default: 256]
#                  dataroot: /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1                             	[default: 3]
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 1024                          	[default: 256]
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
#                      name: pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_256
#                       ngf: 64
#                no_dropout: True                          	[default: False]
#                   no_flip: False
#                      norm: batch
#                  num_test: 191                           	[default: 50]
#               num_threads: 4
#                 output_nc: 1                             	[default: 3]
#                     phase: test
#                preprocess: scale_width                   	[default: resize_and_crop]
#               results_dir: /media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/SYTOX_NIKON1	[default: ./results/]
#            serial_batches: False
#                    suffix:
#                 use_wandb: False
#                   verbose: False
#        wandb_project_name: CycleGAN-and-pix2pix
# ----------------- End -------------------
# dataset [AlignedDataset] was created
# initialize network with normal
# model [Pix2PixModel] was created
# loading the model from /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 54.408 M
# -----------------------------------------------
# creating web directory /media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/SYTOX_NIKON1/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024/test_latest
# processing (0000)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s3_0000.png']
# processing (0005)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s3_0005.png']
# processing (0010)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s3_0010.png']
# processing (0015)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_1s3_0015.png']
# ...
# processing (0060)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0060.png']
# processing (0065)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0065.png']
# processing (0070)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0070.png']
# processing (0075)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0075.png']
# processing (0080)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0080.png']
# processing (0085)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0085.png']
# processing (0090)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0090.png']
# processing (0095)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0095.png']
# processing (0100)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0100.png']
# processing (0105)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0105.png']
# processing (0110)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0110.png']
# processing (0115)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0115.png']
# processing (0120)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0120.png']
# processing (0125)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0125.png']
# processing (0130)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0130.png']
# processing (0135)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0135.png']
# processing (0140)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0140.png']
# processing (0145)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0145.png']
# processing (0150)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0150.png']
# processing (0155)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0155.png']
# processing (0160)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0160.png']
# processing (0165)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0165.png']
# processing (0170)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0170.png']
# processing (0175)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0175.png']
# processing (0180)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C4_0180.png']
# Images processed already
# cho_sync_unsync_sytox_live_Unsync_C5.tif
# ('cho_sync_unsync_sytox_live_Unsync_C5', '.tif') file loaded in python
# Images stored in /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/image_sequence
# /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/image_sequence
# /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data
# [fold_A] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/A
# [fold_B] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/B
# [fold_AB] =  /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB
# [num_imgs] =  1000000
# [use_AB] =  False
# [no_multiprocessing] =  False
# split = test, use 181/181 images
# split = test, number of images = 181
# Images ready to be processed
# AB folder placed in /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB
# Chosen image size to process:  1024
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS	[default: ./checkpoints]
#                 crop_size: 1024                          	[default: 256]
#                  dataroot: /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1                             	[default: 3]
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 1024                          	[default: 256]
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
#                      name: pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_256
#                       ngf: 64
#                no_dropout: True                          	[default: False]
#                   no_flip: False
#                      norm: batch
#                  num_test: 191                           	[default: 50]
#               num_threads: 4
#                 output_nc: 1                             	[default: 3]
#                     phase: test
#                preprocess: scale_width                   	[default: resize_and_crop]
#               results_dir: /media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/SYTOX_NIKON1	[default: ./results/]
#            serial_batches: False
#                    suffix:
#                 use_wandb: False
#                   verbose: False
#        wandb_project_name: CycleGAN-and-pix2pix
# ----------------- End -------------------
# dataset [AlignedDataset] was created
# initialize network with normal
# model [Pix2PixModel] was created
# loading the model from /home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 54.408 M
# -----------------------------------------------
# creating web directory /media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/SYTOX_NIKON1/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024/test_latest
# processing (0000)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0000.png']
# processing (0005)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0005.png']
# processing (0010)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0010.png']
# processing (0015)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0015.png']
# processing (0020)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0020.png']
# processing (0025)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0025.png']
# processing (0030)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0030.png']
# processing (0035)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0035.png']
# processing (0040)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0040.png']
# processing (0045)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0045.png']
# processing (0050)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0050.png']
# processing (0055)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0055.png']
# processing (0060)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0060.png']
# processing (0065)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0065.png']
# processing (0070)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0070.png']
# processing (0075)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0075.png']
# processing (0080)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0080.png']
# processing (0085)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0085.png']
# processing (0090)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0090.png']
# processing (0095)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0095.png']
# processing (0100)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0100.png']
# processing (0105)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0105.png']
# processing (0110)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0110.png']
# processing (0115)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0115.png']
# processing (0120)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0120.png']
# processing (0125)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0125.png']
# processing (0130)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0130.png']
# processing (0135)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0135.png']
# processing (0140)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0140.png']
# processing (0145)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0145.png']
# processing (0150)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0150.png']
# processing (0155)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0155.png']
# processing (0160)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0160.png']
# processing (0165)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0165.png']
# processing (0170)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0170.png']
# processing (0175)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0175.png']
# processing (0180)-th image... ['/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/prepared_data/AB/test/cho_sync_unsync_sytox_live_Unsync_C5_0180.png']
# Images processed already
# ['pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024']
# ['test_latest']
# ['videos_real_A', 'index.html', 'images_fake_B', 'images_real_A', 'videos_fake_B']
# /tmp/ipykernel_310378/3749622943.py:190: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   imsave(os.path.join(path2real_reconstructions, f"{v}.tif"), real_video)
# /tmp/ipykernel_310378/3749622943.py:191: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   imsave(os.path.join(path2fake_reconstructions, f"{v}.tif"), fake_video)
# cho_sync_unsync_sytox_live_Unsync_10s4 processed
# cho_sync_unsync_sytox_live_Unsync_10s5 processed
# cho_sync_unsync_sytox_live_Unsync_1s1 processed
# cho_sync_unsync_sytox_live_Unsync_1s2 processed
# cho_sync_unsync_sytox_live_Unsync_1s3 processed
# cho_sync_unsync_sytox_live_Unsync_1s4 processed
# cho_sync_unsync_sytox_live_Unsync_1s5 processed
# cho_sync_unsync_sytox_live_Unsync_C1 processed
# cho_sync_unsync_sytox_live_Unsync_C2 processed
# cho_sync_unsync_sytox_live_Unsync_C3 processed
# cho_sync_unsync_sytox_live_Unsync_C4 processed
# cho_sync_unsync_sytox_live_Unsync_C5 processed

# %%
#Here, we install libraries which are not already included in Colab.
#!git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
import os
pix2pix_working_directory = "/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/working_dir/"
pix2pix_code_dir = "/home/ocb/HardDrive_4TB/EGM/PHX/PhotoFITT/notebooks/deep-learning/pix2pix/"
#Result_folder = "/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/RESULTS/PHX_DATA"
Result_folder = "/media/ocb/OCB-Data2/PhotoFiTT/PIX2PIX/SYTOX1"

pix2pix_model_path = "/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/pix2pix_cho_selectedz_nuclei_ph_contrast_resized1024_18012024"
#pix2pix_model_path = "/home/ocb/HardDrive_4TB/EGM/MULTICHANNEL/PIX2PIX-MODELS/pix2pix_cho_selectedz_membrane_ph_contrast_resized1024_finetuned29012024_30012024"

path2data = "/media/ocb/OCB-Data2/PhotoFiTT/RAW DATA/SYTOX/20240214_SYTOX/individual"
process_pix2pix(path2data,
                pix2pix_model_path,
                Result_folder,
                pix2pix_code_dir,
                pix2pix_working_directory,
                checkpoint="latest",
                normalisation="Contrast stretching",
                nc=1,
                multichannel=True,
                ch=1)

digest_predictions(Result_folder)
